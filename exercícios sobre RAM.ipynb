# %% [markdown]
#   EXEMPLO 4.1

# %% [markdown]
# total de bits que podem ser armazenados:
# numero de endereços x quantidade de bits em uma  célula
# 2k= 2^1 * 2^10= 2^11
# 2^11 * 2^4= 2^15 -> 2^15= 32k bits
#
# tamanho de cada endereço:
# numero maximo de endereçamentos= 2k= 2^11
# o exponte indica a quantidade de bits por endereço, logo cada endereço possui um tamanho de 11 bits

# %% [markdown]
# EXEMPLO 4.2

# %% [markdown]
# tamanho de cada endereço:
# armazenamento total= 256k= 2^18
# num. de endereço = armz total / bits por celula
#                  = 2^18/ 2^3= 2^15
# o exponte indica a quantidade de bits por endereço, logo cada endereço possui um tamanho de 15 bits
#
# total de celulas:
# n. de celulas = n. de endereços
# logo, a quantidade de celulas nessa memoria é 2^15= 32k celulas

# %% [markdown]
# EXEMPLO 4.3

# %% [markdown]
# numero de endereços= 2k= 2^11
# tamanho celula= 16 bits
# tamnho REM:
# o REM tem um tamanho de 11 bits, ja que cada endereço possui 11 bits
#
# tamanho RDM:
# o RDM tem um tamanho de 16 bits, ja que cada celula tem um tamanho de 16 bitS
#
# maior endereço:
# 11111111111 -> valor maximo representado por 11 bits
#
# quantidade total de bits na MP:
# 2^11 * 2^4= 2^15= 32k bits

# %% [markdown]
# EXEMPLO 4.4

# %% [markdown]
# a) numero de endereços= 2^24= 16M, ja que a capacidade do REM é 24 bits
#
# b) 2^24 * 2^4= 2^28= 256M bits
#
# c)Cada palavra possui 32 bits, ja que o RDM tem capacidade de 32 bits, e cada celula possui 16 bits, ja que a cada acesso sao lidas duas celulas

# %% [markdown]
# EXEMPLO 4.5

# %% [markdown]
# a) BE = n. de bits por endereço
# n. de endereços = n. de celulas
# 2^33= 8G celulas
#
# b) tamanho REM = tamanho BE
# logo o tamanho do REM é igual a 33 bits
# tamanho do BD= 256 bits, pois
#
# tamanho da celula= 2^36 / 2^33= 2^3= 8 bits por celula, sendo que 8 é igual a 1/8 da palavra, logo cada palavra tem um tamanho de 64 bits e o BD transfere 4 palavras por acesso, por isso possui um tamanho de 256 bits(64*4)
#
# c) tamanho da celula= 8 bits
#
# tamanho da palavra é 64 bits

# %% [markdown]
# 1)

# %% [markdown]
# 2^12 * 2^4= 2^16= 64k bits
#
# 2^16 / 2^3= 2^13= 8k bytes

# %% [markdown]
# 5.

# %% [markdown]
# a) endereço: 15 bits, conteudo: 8, total de bits: 2^15 * 2^3= 2^18= 256k bits
#
# b) endereço: 14 bits, conteudo: 16, total de bits: 2^14 * 2^4= 2^18= 256k bits
#
# c) endereço: 14 bits, conteudo: 8, total de bits: 2^14 * 2^3= 2^17= 128k bits

# %% [markdown]
# 6.

# %% [markdown]
# REM: armazenar os endereços no processador, para indentificar na memoria a celula a ser lida ou escrita
#
# RDM: responsavel por armazenar os dados vindos da MP(leitura) ou que serão levados para a MP(escrita)

# %% [markdown]
# 7.

# %% [markdown]
# BD: UCP-> MP(escrita) MP-> UCP(leitura) bidirecional
#
# BE: UCP-> MP, transferencia dos bits que localizam o endereço, unidirecional
#
# Barramento de controle: UCP-> MP, indicam se o proceso é de escrita ou leitura para a MP

# %% [markdown]
# 8.

# %% [markdown]
# UCP -> BE -> MP; UCP -> BC(barramento de controle) -> leitura -> MP; MP -> BD -> UCP

# %% [markdown]
# 9.

# %% [markdown]
# UCP -> BE -> MP; UCP -> BC(barramento de controle) -> escrita -> MP; UCP -> BD -> MP

# %% [markdown]
# 10.

# %% [markdown]
# a) REM=BE, logo o tamanho do BE é igual a 20 bits
#
# b) São lidas 2 celulas por operação, já que o RDM possui 16 bits
#
# c) 2^20 * 2^3= 2^23= 8M bits

# %% [markdown]
# 11.

# %% [markdown]
# a) 32k= 2^15 -> 15 bits por endereço, logo o valor maximo em binario seria 111111111111111 e em decimal seria 127
#
# b) 15 bits
#
# c) REM= 15 bits, RDM= 8 bits
#
# d) 2^15 * 2^3= 2^18= 256k bits

# %% [markdown]
# 12.

# %% [markdown]
# a) REM= 16 bits, RDM= 12 bits
#
# b) 2^16 * 12= 758k bits

# %% [markdown]
# 13.

# %% [markdown]
# é um caractere por celula, ja que cada celula armazena 1 byte e um caractere tem 8 bits
#
# do A ao I possuem 9 letras, 9 * 128= 1152
# bytes= 1152 celulas
#
# 27FA= 0010011111111010(em binario) + 10010000000(1152 em binario)=   0010110001111010(11386)= 2C7A em hexadecimal o endereço

# %% [markdown]
# 14.

# %% [markdown]
# SRAM= 1 + 0,00002N
#
# DRAM​ =5 + 0,00001N
#
# 1 + 0,00002N = 5 + 0,00001N; N=400000, logo em 400000 bits os custos sao iguais, para valores abaixo a dram fica mais barata e para valores acima a sram fica mais barata

# %% [markdown]
# 21)

# %% [markdown]
#  levando em consideração que a eficiencia é de 96%, em 100 acessos, 96 serao acertos e 4 serao erros, ou seja, 96 vezes os dados serao encontrados na memoria cache e 4 vezes esse dado terá que ser buscado no disco rigido.
#
# 96 * 8 + 4 * 78= 1080ns/100= 10,8ns em media

# %% [markdown]
# 26.

# %% [markdown]
# Decodificador 3×8 — com 3 linhas de endereço é possível selecionar 1 dentre 8 células.
#
# Células de memória — cada linha do decodificador ativa uma das 8 células. Os bits armazenados correspondem à presença ou ausência de conexão entre a linha de endereço e a linha de bit.
#
# Portas OR — cada coluna de bit passa por uma porta OR com 8 entradas. Quando um endereço é selecionado, apenas as conexões presentes naquela linha propagam lógica 1 para a saída correspondente.

# %% [markdown]
# 27.

# %% [markdown]
# 128G= 2^7 * 2^30= 2^37 -> 37 bits

# %% [markdown]
# 28.

# %% [markdown]
# 32k= 2^5 * 2^10= 2^15 -> 15 bits

# %% [markdown]
# 31.

# %% [markdown]
# a) 640 * 420= 268800 pontos * 4= 1075200 bytes
#
# b) 1075200 * 10= 10752000 bytes / 2^20= 10,25M bytes
#
# c) 10 imagens - 10,25 Mbytes
#
#         x ----- 128 Mbytes
#
#       x= 1280/ 10,25= 124 imagens

# %% [markdown]
# 32.

# %% [markdown]
# 2^16 * 2^2= 2^18= 256k bits / 2^3= 32k bytes

# %% [markdown]
# 33.

# %% [markdown]
# não, pois o armazenamento é ligado a capacidade da memoria ram e a capacidade do disco rigido, o processador auxilia na velocidade de execução dos programas, por exemplo.

# %% [markdown]
# 34.

# %% [markdown]
# não, pois ao aumentar a capacidade da MP o acesso ao disco rigido não será mais rapido, no entanto, ao aumentar a capacidade da MP será menos recorrente o acesso ao meio magnetico, ja que a memoria ram armazenaria mais dados, o que aumentaria a velocidade de execução dos programas,  tendo em vista que a velocidade de acesso a memoria ram é mais rapida que o acesso aos meios magneticos.
